# %%
import pandas as pd
df = pd.read_csv('UserBehavior.csv', names=['user_id','item_id','category_id','behavior_type','timestamp'])
print(df.head(10))
print(df['behavior_type'].value_counts())
# Out:
#    user_id  item_id  category_id behavior_type   timestamp
# 0   543462     1715      1464116            pv  1511658000
# 1   662867  2244074      1575622            pv  1511658000
# 2   561558  3611281       965809            pv  1511658000
# 3   894923  3076029      1879194            pv  1511658000
# 4   834377  4541270      3738615            pv  1511658000
# 5   315321   942195      4339722            pv  1511658000
# 6   625915  1162383       570735            pv  1511658000
# 7   578814   176722       982926            pv  1511658000
# 8   873335  1256540      1451783            pv  1511658000
# 9   429984  4625350      2355072            pv  1511658000
# behavior_type
# pv      434349
# cart     25824
# fav      14396
# buy      11161
# Name: count, dtype: int64
